# %%
import pandas as pd

# %%
merged = pd.read_csv('merged_data/merged_data.csv')

# %%
merged
# Out:
#         Unnamed: 0       Brand   Model    mass  wheel_base  axle_width_other  \
# 0                0  Alfa Romeo  Giulia  1620.0      2820.0            1629.0
# 1                1  Alfa Romeo  Giulia  1640.0      2820.0            1629.0
# 2                2  Alfa Romeo  Giulia  1570.0      2820.0            1641.0
# 3                3  Alfa Romeo  Giulia  1640.0      2820.0            1629.0
# 4                4  Alfa Romeo  Giulia  1570.0      2820.0            1641.0
# ...            ...         ...     ...     ...         ...               ...
# 211113    11805865       Volvo    Xc90  2210.0      2984.0            1674.0
# 211114    11805868       Volvo    Xc90  2181.0      2984.0            1674.0
# 211115    11805875       Volvo    Xc90  2211.0      2984.0            1674.0
# 211116    11805882       Volvo    Xc90  2206.0      2984.0            1666.0
# 211117    11805996       Volvo    Xc90  2170.0      2984.0            1675.0
#
# ...
